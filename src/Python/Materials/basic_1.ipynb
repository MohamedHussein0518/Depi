# %%
x = 5
x
# Out:
# 5

# %%
print(f"my Age is {30}")
# Out:
# my Age is 30

# %%
# Local style coding
# 
'''
DocSring
'''
type(x)
# Out:
# int

# %%
print(f"My name is {'Mohamed'} , and I am {21} years old. I am engaged in learning {'machine learning snd AI diplona'}")
# Out:
# My name is Mohamed , and I am 21 years old. I am engaged in learning machine learning snd AI diplona

# %%
myname = "Mohamed"
age = 21
course = "machine learning and AI diploma"
print(f"My name is {myname} , and I am {age} years old. I am engaged in learning {course}")
# Out:
# My name is Mohamed , and I am 21 years old. I am engaged in learning machine learning and AI diploma

# %%
name = "amit learning"
print(name[-1]) 
print(name[0:4])
# Out:
# g
# amit

# %%
m = '0123456789'
print(m[-2:-6:-2])
# Out:
# 86

# %%
def string_to_list(w: str) -> list[str]:
    """
    transform sentence from string to list.

    Parameters
    ----------
    nuwm : str
        sentence of word.

    Returns
    -------
    list of string
        list contains word of sentence.
    """

    lst = w.split()
    return lst

# %%
string_to_list("Mohamed Hussein Ramadan")
# Out:
# ['Mohamed', 'Hussein', 'Ramadan']
